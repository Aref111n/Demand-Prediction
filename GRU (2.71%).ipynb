# %%
import pandas as pd

file_path = '/kaggle/input/demand/reversed_finaldatacsv.xlsx'

df = pd.read_excel(file_path)
df.head()
# Out:
#               Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  Coal
# 0  01-01-2016 08:00:00          4140.0        4140  3734          113     0
# 1  01-01-2016 09:00:00          3941.0        3941  3551          113     0
# 2  01-01-2016 10:00:00          3724.0        3724  3286          133     0
# 3  01-01-2016 11:00:00          3603.0        3603  3168          130     0
# 4  01-01-2016 12:00:00          3590.0        3590  3145          140     0

# %%
df['Datetime_formatted'] = pd.to_datetime(df['Datetime'], format='%d-%m-%Y %H:%M:%S')

# %%
df
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 0      01-01-2016 08:00:00          4140.0        4140  3734          113
# 1      01-01-2016 09:00:00          3941.0        3941  3551          113
# 2      01-01-2016 10:00:00          3724.0        3724  3286          133
# 3      01-01-2016 11:00:00          3603.0        3603  3168          130
# 4      01-01-2016 12:00:00          3590.0        3590  3145          140
# ...                    ...             ...         ...   ...          ...
# 70464  15-01-2024 08:00:00          8619.0        8619  4331          866
# 70465  15-01-2024 09:00:00          9018.0        9018  4224         1202
# 70466  15-01-2024 10:00:00          9162.0        9162  4223         1300
# 70467  15-01-2024 11:00:00          9211.0        9211  4101         1427
# 70468  15-01-2024 12:00:00          9335.0        9335  4133         1428
#
#        Coal  Datetime_formatted
# 0         0 2016-01-01 08:00:00
# 1         0 2016-01-01 09:00:00
# 2         0 2016-01-01 10:00:00
# 3         0 2016-01-01 11:00:00
# 4         0 2016-01-01 12:00:00
# ...     ...                 ...
# 70464  2434 2024-01-15 08:00:00
# 70465  2572 2024-01-15 09:00:00
# 70466  2573 2024-01-15 10:00:00
# 70467  2567 2024-01-15 11:00:00
# 70468  2566 2024-01-15 12:00:00
#
# [70469 rows x 7 columns]

# %%
daily_counts = df.groupby(df['Datetime_formatted'].dt.date).size()
daily_counts
# Out:
# Datetime_formatted
# 2016-01-01    16
# 2016-01-02    24
# 2016-01-03    24
# 2016-01-04    24
# 2016-01-05    24
#               ..
# 2024-01-11    24
# 2024-01-12    24
# 2024-01-13    24
# 2024-01-14    24
# 2024-01-15    13
# Length: 2937, dtype: int64

# %%
num_days_with_24_entries = (daily_counts == 24).sum()
num_days_with_24_entries
# Out:
# 2935

# %%
dates_to_keep = daily_counts[daily_counts == 24].index
df_filtered = df[df['Datetime_formatted'].dt.date.isin(dates_to_keep)]
df_filtered
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 16     02-01-2016 00:00:00          3737.0        3737  3269          123
# 17     02-01-2016 01:00:00          4023.0        4023  3312          198
# 18     02-01-2016 02:00:00          5606.0        5606  3786         1313
# 19     02-01-2016 03:00:00          5847.0        5847  4235         1099
# 20     02-01-2016 04:00:00          5880.0        5880  4287         1080
# ...                    ...             ...         ...   ...          ...
# 70451  14-01-2024 19:00:00         10209.0       10209  4240         2459
# 70452  14-01-2024 20:00:00         10289.0       10289  4369         2391
# 70453  14-01-2024 21:00:00         10004.0       10004  4421         2099
# 70454  14-01-2024 22:00:00          9560.0        9560  4237         1864
# 70455  14-01-2024 23:00:00          8793.0        8793  4192         1168
#
#        Coal  Datetime_formatted
# 16        0 2016-01-02 00:00:00
# 17        0 2016-01-02 01:00:00
# 18        0 2016-01-02 02:00:00
# 19        0 2016-01-02 03:00:00
# 20        0 2016-01-02 04:00:00
# ...     ...                 ...
# 70451  2464 2024-01-14 19:00:00
# 70452  2513 2024-01-14 20:00:00
# 70453  2406 2024-01-14 21:00:00
# 70454  2381 2024-01-14 22:00:00
# 70455  2355 2024-01-14 23:00:00
#
# [70440 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)
# Out:
# <ipython-input-40-1d42b4394300>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# %%
demand_data = df_filtered['Demand(MW)'].values

# %%
demand_data
# Out:
# array([ 3737,  4023,  5606, ..., 10004,  9560,  8793])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(demand_data.reshape(-1, 1))
data_scaled
# Out:
# array([[0.20734689],
#        [0.22324108],
#        [0.31121485],
#        ...,
#        [0.55562965],
#        [0.53095476],
#        [0.48832944]])

# %%
train_samples = 2800 * 24
val_samples = 2 * 24
test_samples = 2 * 24
look_back = 24

# %%
def create_dataset(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i + look_back])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

# %%
train_data = data_scaled[:train_samples]  
val_data = data_scaled[train_samples:train_samples + val_samples]  
test_data = data_scaled[train_samples + val_samples:train_samples + val_samples + test_samples]

# %%
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)
X_val, y_val = create_dataset(val_data, look_back)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

# %%
from tensorflow.keras import regularizers

model = tf.keras.Sequential([
    tf.keras.layers.GRU(256, return_sequences=True, input_shape=(look_back, 1), 
                        kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01)),
    tf.keras.layers.Dropout(0.5),
    
    tf.keras.layers.GRU(64, return_sequences=True, 
                        kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01)),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.GRU(32, return_sequences=False, 
                        kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01)),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(1)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,         # Number of epochs to wait before stopping
    restore_best_weights=True  # Restore the best model weights
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=0.5,          # Reduce learning rate by a factor of 0.5
    patience=5,          # Wait 5 epochs before reducing
    min_lr=1e-6          # Minimum learning rate
)

# %%
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001), loss='mse')

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,  # Increase epochs since early stopping will handle stopping
    batch_size=128,
    verbose=1,
    callbacks=[early_stopping, lr_scheduler]  # Add callbacks
)
# Out:
# Epoch 1/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1.7403 - val_loss: 0.0282 - learning_rate: 0.0010
# Epoch 2/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0161 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 3/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0147 - val_loss: 0.0193 - learning_rate: 0.0010
# Epoch 4/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0136 - val_loss: 0.0132 - learning_rate: 0.0010
# Epoch 5/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0125 - val_loss: 0.0112 - learning_rate: 0.0010
# Epoch 6/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0123 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 7/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0120 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 8/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0118 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 9/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0114 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 10/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0111 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 11/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0072 - val_loss: 0.0065 - learning_rate: 5.0000e-04
# Epoch 12/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0069 - val_loss: 0.0053 - learning_rate: 5.0000e-04
# Epoch 13/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0068 - val_loss: 0.0119 - learning_rate: 5.0000e-04
# Epoch 14/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0068 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 15/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0068 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 16/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0068 - val_loss: 0.0125 - learning_rate: 5.0000e-04
# Epoch 17/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0068 - val_loss: 0.0067 - learning_rate: 5.0000e-04
# Epoch 18/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0050 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 19/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0049 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 20/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0049 - val_loss: 0.0037 - learning_rate: 2.5000e-04
# Epoch 21/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0051 - val_loss: 0.0038 - learning_rate: 2.5000e-04
# Epoch 22/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0048 - val_loss: 0.0039 - learning_rate: 2.5000e-04
# Epoch 23/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0049 - val_loss: 0.0036 - learning_rate: 2.5000e-04
# Epoch 24/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 25/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0040 - learning_rate: 1.2500e-04
# Epoch 26/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0041 - learning_rate: 1.2500e-04
# Epoch 27/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0050 - learning_rate: 1.2500e-04
# Epoch 28/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0031 - learning_rate: 1.2500e-04
# Epoch 29/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0047 - learning_rate: 1.2500e-04
# Epoch 30/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0045 - learning_rate: 1.2500e-04
# Epoch 31/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0027 - learning_rate: 1.2500e-04
# Epoch 32/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0040 - val_loss: 0.0037 - learning_rate: 1.2500e-04
# Epoch 33/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0034 - learning_rate: 1.2500e-04
# Epoch 34/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0042 - learning_rate: 1.2500e-04
# Epoch 35/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0034 - learning_rate: 1.2500e-04
# Epoch 36/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0025 - learning_rate: 1.2500e-04
# Epoch 37/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0036 - learning_rate: 1.2500e-04
# Epoch 38/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0030 - learning_rate: 1.2500e-04
# Epoch 39/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0040 - learning_rate: 1.2500e-04
# Epoch 40/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0039 - val_loss: 0.0029 - learning_rate: 1.2500e-04
# Epoch 41/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0038 - val_loss: 0.0058 - learning_rate: 1.2500e-04
# Epoch 42/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0034 - val_loss: 0.0020 - learning_rate: 6.2500e-05
# Epoch 43/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0033 - val_loss: 0.0044 - learning_rate: 6.2500e-05
# Epoch 44/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0034 - val_loss: 0.0043 - learning_rate: 6.2500e-05
# Epoch 45/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0033 - val_loss: 0.0047 - learning_rate: 6.2500e-05
# Epoch 46/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0034 - val_loss: 0.0042 - learning_rate: 6.2500e-05
# Epoch 47/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0034 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 48/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0031 - val_loss: 0.0034 - learning_rate: 3.1250e-05
# Epoch 49/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0031 - val_loss: 0.0023 - learning_rate: 3.1250e-05
# Epoch 50/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0031 - val_loss: 0.0027 - learning_rate: 3.1250e-05
# Epoch 51/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0031 - val_loss: 0.0038 - learning_rate: 3.1250e-05
# Epoch 52/100
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0032 - val_loss: 0.0027 - learning_rate: 3.1250e-05

# %%
loss_history = pd.DataFrame({
    'epoch': range(1, len(history.history['loss']) + 1),
    'train_loss': history.history['loss'],
    'val_loss': history.history['val_loss']  
})

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'][1:], label='Training Loss')
plt.plot(history.history['val_loss'][1:], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('loss_plot.png')  # Save the plot as an image
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step

# %%
y_pred_inverse = scaler.inverse_transform(y_pred)
y_test_inverse = scaler.inverse_transform(y_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse))
mse = mean_squared_error(y_test_inverse, y_pred_inverse) 
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_inverse)
r2 = r2_score(y_test_inverse, y_pred_inverse)

# %%
print(f" RMSE:{rmse},\n MSE:{mse},\n MAPE:{mape*100}%,\n R-Squared:{r2}")
# Out:
#  RMSE:447.75527867891793,
#  MSE:200484.78958483544,
#  MAPE:2.718040199370231%,
#  R-Squared:0.5556952837487392

# %%
import matplotlib.pyplot as plt

# Plot Actual vs Predicted Demand
plt.figure(figsize=(12, 6))
plt.plot(y_test_inverse.flatten(), label='Actual Demand', color='blue', alpha=0.7)
plt.plot(y_pred_inverse.flatten(), label='Predicted Demand', color='orange', alpha=0.7)
plt.title('Actual vs Predicted Demand')
plt.xlabel('Time Steps')
plt.ylabel('Demand (MW)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd

file_path = '/kaggle/input/demand/reversed_finaldatacsv.xlsx'

df = pd.read_excel(file_path)
df.head()
# Out:
#               Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  Coal
# 0  01-01-2016 08:00:00          4140.0        4140  3734          113     0
# 1  01-01-2016 09:00:00          3941.0        3941  3551          113     0
# 2  01-01-2016 10:00:00          3724.0        3724  3286          133     0
# 3  01-01-2016 11:00:00          3603.0        3603  3168          130     0
# 4  01-01-2016 12:00:00          3590.0        3590  3145          140     0

# %%
df['Datetime_formatted'] = pd.to_datetime(df['Datetime'], format='%d-%m-%Y %H:%M:%S')

# %%
df
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 0      01-01-2016 08:00:00          4140.0        4140  3734          113
# 1      01-01-2016 09:00:00          3941.0        3941  3551          113
# 2      01-01-2016 10:00:00          3724.0        3724  3286          133
# 3      01-01-2016 11:00:00          3603.0        3603  3168          130
# 4      01-01-2016 12:00:00          3590.0        3590  3145          140
# ...                    ...             ...         ...   ...          ...
# 70464  15-01-2024 08:00:00          8619.0        8619  4331          866
# 70465  15-01-2024 09:00:00          9018.0        9018  4224         1202
# 70466  15-01-2024 10:00:00          9162.0        9162  4223         1300
# 70467  15-01-2024 11:00:00          9211.0        9211  4101         1427
# 70468  15-01-2024 12:00:00          9335.0        9335  4133         1428
#
#        Coal  Datetime_formatted
# 0         0 2016-01-01 08:00:00
# 1         0 2016-01-01 09:00:00
# 2         0 2016-01-01 10:00:00
# 3         0 2016-01-01 11:00:00
# 4         0 2016-01-01 12:00:00
# ...     ...                 ...
# 70464  2434 2024-01-15 08:00:00
# 70465  2572 2024-01-15 09:00:00
# 70466  2573 2024-01-15 10:00:00
# 70467  2567 2024-01-15 11:00:00
# 70468  2566 2024-01-15 12:00:00
#
# [70469 rows x 7 columns]

# %%
daily_counts = df.groupby(df['Datetime_formatted'].dt.date).size()
daily_counts
# Out:
# Datetime_formatted
# 2016-01-01    16
# 2016-01-02    24
# 2016-01-03    24
# 2016-01-04    24
# 2016-01-05    24
#               ..
# 2024-01-11    24
# 2024-01-12    24
# 2024-01-13    24
# 2024-01-14    24
# 2024-01-15    13
# Length: 2937, dtype: int64

# %%
num_days_with_24_entries = (daily_counts == 24).sum()
num_days_with_24_entries
# Out:
# 2935

# %%
dates_to_keep = daily_counts[daily_counts == 24].index
df_filtered = df[df['Datetime_formatted'].dt.date.isin(dates_to_keep)]
df_filtered
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 16     02-01-2016 00:00:00          3737.0        3737  3269          123
# 17     02-01-2016 01:00:00          4023.0        4023  3312          198
# 18     02-01-2016 02:00:00          5606.0        5606  3786         1313
# 19     02-01-2016 03:00:00          5847.0        5847  4235         1099
# 20     02-01-2016 04:00:00          5880.0        5880  4287         1080
# ...                    ...             ...         ...   ...          ...
# 70451  14-01-2024 19:00:00         10209.0       10209  4240         2459
# 70452  14-01-2024 20:00:00         10289.0       10289  4369         2391
# 70453  14-01-2024 21:00:00         10004.0       10004  4421         2099
# 70454  14-01-2024 22:00:00          9560.0        9560  4237         1864
# 70455  14-01-2024 23:00:00          8793.0        8793  4192         1168
#
#        Coal  Datetime_formatted
# 16        0 2016-01-02 00:00:00
# 17        0 2016-01-02 01:00:00
# 18        0 2016-01-02 02:00:00
# 19        0 2016-01-02 03:00:00
# 20        0 2016-01-02 04:00:00
# ...     ...                 ...
# 70451  2464 2024-01-14 19:00:00
# 70452  2513 2024-01-14 20:00:00
# 70453  2406 2024-01-14 21:00:00
# 70454  2381 2024-01-14 22:00:00
# 70455  2355 2024-01-14 23:00:00
#
# [70440 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)
# Out:
# <ipython-input-10-1d42b4394300>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# %%
demand_data = df_filtered['Demand(MW)'].values

# %%
demand_data
# Out:
# array([ 3737,  4023,  5606, ..., 10004,  9560,  8793])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(demand_data.reshape(-1, 1))
data_scaled
# Out:
# array([[0.20734689],
#        [0.22324108],
#        [0.31121485],
#        ...,
#        [0.55562965],
#        [0.53095476],
#        [0.48832944]])

# %%
train_samples = 2800 * 24
val_samples = 2 * 24
test2_samples = 2 * 24
test7_samples = 7 * 24
look_back = 24

# %%
def create_dataset(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i + look_back])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

# %%
train_data = data_scaled[:train_samples]  
val_data = data_scaled[train_samples:train_samples + val_samples]  
test2_data = data_scaled[train_samples + val_samples:train_samples + val_samples + test2_samples] 
test7_data = data_scaled[train_samples + val_samples + test2_samples:train_samples + val_samples + test2_samples + test7_samples]

# %%
X_train, y_train = create_dataset(train_data, look_back)
X_test2, y_test2 = create_dataset(test2_data, look_back)
X_test7, y_test7 = create_dataset(test7_data, look_back)
X_val, y_val = create_dataset(val_data, look_back)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1])
X_test2 = X_test2.reshape(X_test2.shape[0], X_test2.shape[1])
X_test7 = X_test7.reshape(X_test7.shape[0], X_test7.shape[1])
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1])

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=500,  
    learning_rate=0.01,  
    max_depth=6,  
    subsample=0.8,  
    colsample_bytree=0.8,  
    reg_lambda=0.1, 
    reg_alpha=0.1, 
    objective='reg:squarederror',
    random_state=42
)

# %%
evals_result = {}

# Train the model while tracking loss
xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],  # Track both train and val loss
    eval_metric='rmse',  # Root Mean Squared Error (RMSE) as the metric
    early_stopping_rounds=10,
    verbose=True
)
# Out:
# [0]	validation_0-rmse:0.12704	validation_1-rmse:0.28003
# [1]	validation_0-rmse:0.12583	validation_1-rmse:0.27735
# [2]	validation_0-rmse:0.12467	validation_1-rmse:0.27478
# [3]	validation_0-rmse:0.12352	validation_1-rmse:0.27220
# [4]	validation_0-rmse:0.12235	validation_1-rmse:0.26956
# [5]	validation_0-rmse:0.12119	validation_1-rmse:0.26698
# [6]	validation_0-rmse:0.12004	validation_1-rmse:0.26438
# [7]	validation_0-rmse:0.11890	validation_1-rmse:0.26182
# [8]	validation_0-rmse:0.11777	validation_1-rmse:0.25930
# [9]	validation_0-rmse:0.11666	validation_1-rmse:0.25679
# [10]	validation_0-rmse:0.11555	validation_1-rmse:0.25433
# [11]	validation_0-rmse:0.11446	validation_1-rmse:0.25188
# [12]	validation_0-rmse:0.11339	validation_1-rmse:0.24945
# [13]	validation_0-rmse:0.11232	validation_1-rmse:0.24704
# [14]	validation_0-rmse:0.11130	validation_1-rmse:0.24476
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.11025	validation_1-rmse:0.24242
# [16]	validation_0-rmse:0.10922	validation_1-rmse:0.24008
# [17]	validation_0-rmse:0.10823	validation_1-rmse:0.23786
# [18]	validation_0-rmse:0.10721	validation_1-rmse:0.23556
# [19]	validation_0-rmse:0.10621	validation_1-rmse:0.23329
# [20]	validation_0-rmse:0.10521	validation_1-rmse:0.23107
# [21]	validation_0-rmse:0.10423	validation_1-rmse:0.22883
# [22]	validation_0-rmse:0.10326	validation_1-rmse:0.22665
# [23]	validation_0-rmse:0.10229	validation_1-rmse:0.22446
# [24]	validation_0-rmse:0.10134	validation_1-rmse:0.22234
# [25]	validation_0-rmse:0.10040	validation_1-rmse:0.22021
# [26]	validation_0-rmse:0.09950	validation_1-rmse:0.21817
# [27]	validation_0-rmse:0.09858	validation_1-rmse:0.21606
# [28]	validation_0-rmse:0.09770	validation_1-rmse:0.21408
# [29]	validation_0-rmse:0.09679	validation_1-rmse:0.21205
# [30]	validation_0-rmse:0.09590	validation_1-rmse:0.21002
# [31]	validation_0-rmse:0.09501	validation_1-rmse:0.20805
# [32]	validation_0-rmse:0.09417	validation_1-rmse:0.20616
# [33]	validation_0-rmse:0.09330	validation_1-rmse:0.20416
# [34]	validation_0-rmse:0.09244	validation_1-rmse:0.20221
# [35]	validation_0-rmse:0.09160	validation_1-rmse:0.20029
# [36]	validation_0-rmse:0.09079	validation_1-rmse:0.19843
# [37]	validation_0-rmse:0.09001	validation_1-rmse:0.19664
# [38]	validation_0-rmse:0.08919	validation_1-rmse:0.19477
# [39]	validation_0-rmse:0.08837	validation_1-rmse:0.19293
# [40]	validation_0-rmse:0.08757	validation_1-rmse:0.19108
# [41]	validation_0-rmse:0.08677	validation_1-rmse:0.18925
# [42]	validation_0-rmse:0.08598	validation_1-rmse:0.18746
# [43]	validation_0-rmse:0.08520	validation_1-rmse:0.18568
# [44]	validation_0-rmse:0.08443	validation_1-rmse:0.18391
# [45]	validation_0-rmse:0.08367	validation_1-rmse:0.18215
# [46]	validation_0-rmse:0.08291	validation_1-rmse:0.18040
# [47]	validation_0-rmse:0.08221	validation_1-rmse:0.17881
# [48]	validation_0-rmse:0.08147	validation_1-rmse:0.17711
# [49]	validation_0-rmse:0.08079	validation_1-rmse:0.17555
# [50]	validation_0-rmse:0.08010	validation_1-rmse:0.17392
# [51]	validation_0-rmse:0.07938	validation_1-rmse:0.17226
# [52]	validation_0-rmse:0.07867	validation_1-rmse:0.17065
# [53]	validation_0-rmse:0.07797	validation_1-rmse:0.16903
# [54]	validation_0-rmse:0.07728	validation_1-rmse:0.16742
# [55]	validation_0-rmse:0.07659	validation_1-rmse:0.16582
# [56]	validation_0-rmse:0.07591	validation_1-rmse:0.16425
# [57]	validation_0-rmse:0.07524	validation_1-rmse:0.16269
# [58]	validation_0-rmse:0.07458	validation_1-rmse:0.16117
# [59]	validation_0-rmse:0.07392	validation_1-rmse:0.15965
# [60]	validation_0-rmse:0.07327	validation_1-rmse:0.15814
# [61]	validation_0-rmse:0.07263	validation_1-rmse:0.15666
# [62]	validation_0-rmse:0.07199	validation_1-rmse:0.15522
# [63]	validation_0-rmse:0.07136	validation_1-rmse:0.15378
# [64]	validation_0-rmse:0.07077	validation_1-rmse:0.15240
# [65]	validation_0-rmse:0.07015	validation_1-rmse:0.15098
# [66]	validation_0-rmse:0.06955	validation_1-rmse:0.14958
# [67]	validation_0-rmse:0.06897	validation_1-rmse:0.14825
# [68]	validation_0-rmse:0.06838	validation_1-rmse:0.14685
# [69]	validation_0-rmse:0.06782	validation_1-rmse:0.14548
# [70]	validation_0-rmse:0.06723	validation_1-rmse:0.14413
# [71]	validation_0-rmse:0.06666	validation_1-rmse:0.14281
# [72]	validation_0-rmse:0.06609	validation_1-rmse:0.14150
# [73]	validation_0-rmse:0.06553	validation_1-rmse:0.14022
# [74]	validation_0-rmse:0.06497	validation_1-rmse:0.13891
# [75]	validation_0-rmse:0.06445	validation_1-rmse:0.13770
# [76]	validation_0-rmse:0.06390	validation_1-rmse:0.13639
# [77]	validation_0-rmse:0.06339	validation_1-rmse:0.13516
# [78]	validation_0-rmse:0.06288	validation_1-rmse:0.13390
# [79]	validation_0-rmse:0.06236	validation_1-rmse:0.13267
# [80]	validation_0-rmse:0.06184	validation_1-rmse:0.13145
# [81]	validation_0-rmse:0.06132	validation_1-rmse:0.13028
# [82]	validation_0-rmse:0.06081	validation_1-rmse:0.12904
# [83]	validation_0-rmse:0.06033	validation_1-rmse:0.12786
# [84]	validation_0-rmse:0.05983	validation_1-rmse:0.12668
# [85]	validation_0-rmse:0.05937	validation_1-rmse:0.12561
# [86]	validation_0-rmse:0.05891	validation_1-rmse:0.12452
# [87]	validation_0-rmse:0.05843	validation_1-rmse:0.12339
# [88]	validation_0-rmse:0.05795	validation_1-rmse:0.12225
# [89]	validation_0-rmse:0.05748	validation_1-rmse:0.12113
# [90]	validation_0-rmse:0.05702	validation_1-rmse:0.12002
# [91]	validation_0-rmse:0.05656	validation_1-rmse:0.11893
# [92]	validation_0-rmse:0.05610	validation_1-rmse:0.11785
# [93]	validation_0-rmse:0.05568	validation_1-rmse:0.11681
# [94]	validation_0-rmse:0.05523	validation_1-rmse:0.11573
# [95]	validation_0-rmse:0.05479	validation_1-rmse:0.11469
# [96]	validation_0-rmse:0.05436	validation_1-rmse:0.11365
# [97]	validation_0-rmse:0.05393	validation_1-rmse:0.11262
# [98]	validation_0-rmse:0.05350	validation_1-rmse:0.11161
# [99]	validation_0-rmse:0.05308	validation_1-rmse:0.11060
# [100]	validation_0-rmse:0.05269	validation_1-rmse:0.10959
# [101]	validation_0-rmse:0.05228	validation_1-rmse:0.10859
# [102]	validation_0-rmse:0.05190	validation_1-rmse:0.10768
# [103]	validation_0-rmse:0.05150	validation_1-rmse:0.10672
# [104]	validation_0-rmse:0.05112	validation_1-rmse:0.10579
# [105]	validation_0-rmse:0.05073	validation_1-rmse:0.10488
# [106]	validation_0-rmse:0.05034	validation_1-rmse:0.10395
# [107]	validation_0-rmse:0.04996	validation_1-rmse:0.10301
# [108]	validation_0-rmse:0.04958	validation_1-rmse:0.10208
# [109]	validation_0-rmse:0.04923	validation_1-rmse:0.10117
# [110]	validation_0-rmse:0.04887	validation_1-rmse:0.10026
# [111]	validation_0-rmse:0.04852	validation_1-rmse:0.09942
# [112]	validation_0-rmse:0.04816	validation_1-rmse:0.09854
# [113]	validation_0-rmse:0.04783	validation_1-rmse:0.09771
# [114]	validation_0-rmse:0.04747	validation_1-rmse:0.09681
# [115]	validation_0-rmse:0.04712	validation_1-rmse:0.09594
# [116]	validation_0-rmse:0.04678	validation_1-rmse:0.09507
# [117]	validation_0-rmse:0.04644	validation_1-rmse:0.09421
# [118]	validation_0-rmse:0.04613	validation_1-rmse:0.09346
# [119]	validation_0-rmse:0.04579	validation_1-rmse:0.09280
# [120]	validation_0-rmse:0.04547	validation_1-rmse:0.09199
# [121]	validation_0-rmse:0.04516	validation_1-rmse:0.09123
# [122]	validation_0-rmse:0.04484	validation_1-rmse:0.09043
# [123]	validation_0-rmse:0.04453	validation_1-rmse:0.08964
# [124]	validation_0-rmse:0.04422	validation_1-rmse:0.08887
# [125]	validation_0-rmse:0.04391	validation_1-rmse:0.08810
# [126]	validation_0-rmse:0.04361	validation_1-rmse:0.08731
# [127]	validation_0-rmse:0.04331	validation_1-rmse:0.08656
# [128]	validation_0-rmse:0.04301	validation_1-rmse:0.08580
# [129]	validation_0-rmse:0.04272	validation_1-rmse:0.08508
# [130]	validation_0-rmse:0.04243	validation_1-rmse:0.08436
# [131]	validation_0-rmse:0.04215	validation_1-rmse:0.08364
# [132]	validation_0-rmse:0.04186	validation_1-rmse:0.08293
# [133]	validation_0-rmse:0.04159	validation_1-rmse:0.08222
# [134]	validation_0-rmse:0.04133	validation_1-rmse:0.08153
# [135]	validation_0-rmse:0.04108	validation_1-rmse:0.08089
# [136]	validation_0-rmse:0.04081	validation_1-rmse:0.08020
# [137]	validation_0-rmse:0.04054	validation_1-rmse:0.07953
# [138]	validation_0-rmse:0.04028	validation_1-rmse:0.07883
# [139]	validation_0-rmse:0.04003	validation_1-rmse:0.07816
# [140]	validation_0-rmse:0.03979	validation_1-rmse:0.07752
# [141]	validation_0-rmse:0.03954	validation_1-rmse:0.07689
# [142]	validation_0-rmse:0.03931	validation_1-rmse:0.07627
# [143]	validation_0-rmse:0.03907	validation_1-rmse:0.07563
# [144]	validation_0-rmse:0.03885	validation_1-rmse:0.07504
# [145]	validation_0-rmse:0.03861	validation_1-rmse:0.07442
# [146]	validation_0-rmse:0.03837	validation_1-rmse:0.07378
# [147]	validation_0-rmse:0.03815	validation_1-rmse:0.07317
# [148]	validation_0-rmse:0.03792	validation_1-rmse:0.07256
# [149]	validation_0-rmse:0.03770	validation_1-rmse:0.07196
# [150]	validation_0-rmse:0.03749	validation_1-rmse:0.07140
# [151]	validation_0-rmse:0.03727	validation_1-rmse:0.07082
# [152]	validation_0-rmse:0.03705	validation_1-rmse:0.07019
# [153]	validation_0-rmse:0.03683	validation_1-rmse:0.06961
# [154]	validation_0-rmse:0.03662	validation_1-rmse:0.06903
# [155]	validation_0-rmse:0.03641	validation_1-rmse:0.06847
# [156]	validation_0-rmse:0.03620	validation_1-rmse:0.06792
# [157]	validation_0-rmse:0.03601	validation_1-rmse:0.06739
# [158]	validation_0-rmse:0.03582	validation_1-rmse:0.06689
# [159]	validation_0-rmse:0.03564	validation_1-rmse:0.06640
# [160]	validation_0-rmse:0.03545	validation_1-rmse:0.06585
# [161]	validation_0-rmse:0.03525	validation_1-rmse:0.06533
# [162]	validation_0-rmse:0.03506	validation_1-rmse:0.06480
# [163]	validation_0-rmse:0.03487	validation_1-rmse:0.06427
# [164]	validation_0-rmse:0.03469	validation_1-rmse:0.06376
# [165]	validation_0-rmse:0.03450	validation_1-rmse:0.06325
# [166]	validation_0-rmse:0.03432	validation_1-rmse:0.06274
# [167]	validation_0-rmse:0.03415	validation_1-rmse:0.06225
# [168]	validation_0-rmse:0.03398	validation_1-rmse:0.06174
# [169]	validation_0-rmse:0.03380	validation_1-rmse:0.06126
# [170]	validation_0-rmse:0.03363	validation_1-rmse:0.06076
# [171]	validation_0-rmse:0.03347	validation_1-rmse:0.06030
# [172]	validation_0-rmse:0.03331	validation_1-rmse:0.05984
# [173]	validation_0-rmse:0.03315	validation_1-rmse:0.05941
# [174]	validation_0-rmse:0.03300	validation_1-rmse:0.05898
# [175]	validation_0-rmse:0.03284	validation_1-rmse:0.05853
# [176]	validation_0-rmse:0.03268	validation_1-rmse:0.05809
# [177]	validation_0-rmse:0.03253	validation_1-rmse:0.05765
# [178]	validation_0-rmse:0.03237	validation_1-rmse:0.05722
# [179]	validation_0-rmse:0.03222	validation_1-rmse:0.05678
# [180]	validation_0-rmse:0.03209	validation_1-rmse:0.05637
# [181]	validation_0-rmse:0.03194	validation_1-rmse:0.05590
# [182]	validation_0-rmse:0.03181	validation_1-rmse:0.05552
# [183]	validation_0-rmse:0.03166	validation_1-rmse:0.05510
# [184]	validation_0-rmse:0.03152	validation_1-rmse:0.05471
# [185]	validation_0-rmse:0.03139	validation_1-rmse:0.05431
# [186]	validation_0-rmse:0.03125	validation_1-rmse:0.05392
# [187]	validation_0-rmse:0.03112	validation_1-rmse:0.05350
# [188]	validation_0-rmse:0.03098	validation_1-rmse:0.05312
# [189]	validation_0-rmse:0.03085	validation_1-rmse:0.05274
# [190]	validation_0-rmse:0.03072	validation_1-rmse:0.05234
# [191]	validation_0-rmse:0.03059	validation_1-rmse:0.05195
# [192]	validation_0-rmse:0.03047	validation_1-rmse:0.05154
# [193]	validation_0-rmse:0.03035	validation_1-rmse:0.05118
# [194]	validation_0-rmse:0.03023	validation_1-rmse:0.05082
# [195]	validation_0-rmse:0.03011	validation_1-rmse:0.05044
# [196]	validation_0-rmse:0.02999	validation_1-rmse:0.05005
# [197]	validation_0-rmse:0.02987	validation_1-rmse:0.04968
# [198]	validation_0-rmse:0.02975	validation_1-rmse:0.04929
# [199]	validation_0-rmse:0.02964	validation_1-rmse:0.04894
# [200]	validation_0-rmse:0.02952	validation_1-rmse:0.04859
# [201]	validation_0-rmse:0.02941	validation_1-rmse:0.04822
# [202]	validation_0-rmse:0.02931	validation_1-rmse:0.04789
# [203]	validation_0-rmse:0.02920	validation_1-rmse:0.04757
# [204]	validation_0-rmse:0.02911	validation_1-rmse:0.04725
# [205]	validation_0-rmse:0.02901	validation_1-rmse:0.04692
# [206]	validation_0-rmse:0.02890	validation_1-rmse:0.04660
# [207]	validation_0-rmse:0.02880	validation_1-rmse:0.04628
# [208]	validation_0-rmse:0.02870	validation_1-rmse:0.04595
# [209]	validation_0-rmse:0.02861	validation_1-rmse:0.04566
# [210]	validation_0-rmse:0.02851	validation_1-rmse:0.04534
# [211]	validation_0-rmse:0.02841	validation_1-rmse:0.04502
# [212]	validation_0-rmse:0.02832	validation_1-rmse:0.04473
# [213]	validation_0-rmse:0.02823	validation_1-rmse:0.04442
# [214]	validation_0-rmse:0.02814	validation_1-rmse:0.04412
# [215]	validation_0-rmse:0.02805	validation_1-rmse:0.04382
# [216]	validation_0-rmse:0.02796	validation_1-rmse:0.04353
# [217]	validation_0-rmse:0.02788	validation_1-rmse:0.04323
# [218]	validation_0-rmse:0.02779	validation_1-rmse:0.04295
# [219]	validation_0-rmse:0.02770	validation_1-rmse:0.04264
# [220]	validation_0-rmse:0.02762	validation_1-rmse:0.04236
# [221]	validation_0-rmse:0.02754	validation_1-rmse:0.04208
# [222]	validation_0-rmse:0.02746	validation_1-rmse:0.04177
# [223]	validation_0-rmse:0.02738	validation_1-rmse:0.04149
# [224]	validation_0-rmse:0.02730	validation_1-rmse:0.04122
# [225]	validation_0-rmse:0.02723	validation_1-rmse:0.04098
# [226]	validation_0-rmse:0.02716	validation_1-rmse:0.04073
# [227]	validation_0-rmse:0.02708	validation_1-rmse:0.04048
# [228]	validation_0-rmse:0.02701	validation_1-rmse:0.04021
# [229]	validation_0-rmse:0.02693	validation_1-rmse:0.03996
# [230]	validation_0-rmse:0.02686	validation_1-rmse:0.03969
# [231]	validation_0-rmse:0.02679	validation_1-rmse:0.03946
# [232]	validation_0-rmse:0.02672	validation_1-rmse:0.03920
# [233]	validation_0-rmse:0.02665	validation_1-rmse:0.03895
# [234]	validation_0-rmse:0.02658	validation_1-rmse:0.03870
# [235]	validation_0-rmse:0.02651	validation_1-rmse:0.03846
# [236]	validation_0-rmse:0.02645	validation_1-rmse:0.03824
# [237]	validation_0-rmse:0.02639	validation_1-rmse:0.03801
# [238]	validation_0-rmse:0.02633	validation_1-rmse:0.03777
# [239]	validation_0-rmse:0.02626	validation_1-rmse:0.03754
# [240]	validation_0-rmse:0.02620	validation_1-rmse:0.03730
# [241]	validation_0-rmse:0.02614	validation_1-rmse:0.03708
# [242]	validation_0-rmse:0.02608	validation_1-rmse:0.03684
# [243]	validation_0-rmse:0.02602	validation_1-rmse:0.03663
# [244]	validation_0-rmse:0.02596	validation_1-rmse:0.03642
# [245]	validation_0-rmse:0.02590	validation_1-rmse:0.03619
# [246]	validation_0-rmse:0.02585	validation_1-rmse:0.03598
# [247]	validation_0-rmse:0.02579	validation_1-rmse:0.03575
# [248]	validation_0-rmse:0.02573	validation_1-rmse:0.03552
# [249]	validation_0-rmse:0.02568	validation_1-rmse:0.03530
# [250]	validation_0-rmse:0.02562	validation_1-rmse:0.03511
# [251]	validation_0-rmse:0.02557	validation_1-rmse:0.03491
# [252]	validation_0-rmse:0.02552	validation_1-rmse:0.03474
# [253]	validation_0-rmse:0.02547	validation_1-rmse:0.03454
# [254]	validation_0-rmse:0.02542	validation_1-rmse:0.03432
# [255]	validation_0-rmse:0.02537	validation_1-rmse:0.03410
# [256]	validation_0-rmse:0.02532	validation_1-rmse:0.03389
# [257]	validation_0-rmse:0.02527	validation_1-rmse:0.03367
# [258]	validation_0-rmse:0.02522	validation_1-rmse:0.03348
# [259]	validation_0-rmse:0.02517	validation_1-rmse:0.03328
# [260]	validation_0-rmse:0.02512	validation_1-rmse:0.03310
# [261]	validation_0-rmse:0.02508	validation_1-rmse:0.03290
# [262]	validation_0-rmse:0.02503	validation_1-rmse:0.03271
# [263]	validation_0-rmse:0.02498	validation_1-rmse:0.03253
# [264]	validation_0-rmse:0.02494	validation_1-rmse:0.03236
# [265]	validation_0-rmse:0.02490	validation_1-rmse:0.03220
# [266]	validation_0-rmse:0.02486	validation_1-rmse:0.03202
# [267]	validation_0-rmse:0.02481	validation_1-rmse:0.03185
# [268]	validation_0-rmse:0.02477	validation_1-rmse:0.03167
# [269]	validation_0-rmse:0.02473	validation_1-rmse:0.03148
# [270]	validation_0-rmse:0.02469	validation_1-rmse:0.03131
# [271]	validation_0-rmse:0.02465	validation_1-rmse:0.03115
# [272]	validation_0-rmse:0.02461	validation_1-rmse:0.03099
# [273]	validation_0-rmse:0.02457	validation_1-rmse:0.03083
# [274]	validation_0-rmse:0.02453	validation_1-rmse:0.03066
# [275]	validation_0-rmse:0.02449	validation_1-rmse:0.03051
# [276]	validation_0-rmse:0.02445	validation_1-rmse:0.03037
# [277]	validation_0-rmse:0.02442	validation_1-rmse:0.03021
# [278]	validation_0-rmse:0.02438	validation_1-rmse:0.03008
# [279]	validation_0-rmse:0.02435	validation_1-rmse:0.02996
# [280]	validation_0-rmse:0.02432	validation_1-rmse:0.02981
# [281]	validation_0-rmse:0.02428	validation_1-rmse:0.02965
# [282]	validation_0-rmse:0.02424	validation_1-rmse:0.02949
# [283]	validation_0-rmse:0.02421	validation_1-rmse:0.02934
# [284]	validation_0-rmse:0.02418	validation_1-rmse:0.02920
# [285]	validation_0-rmse:0.02414	validation_1-rmse:0.02905
# [286]	validation_0-rmse:0.02411	validation_1-rmse:0.02890
# [287]	validation_0-rmse:0.02409	validation_1-rmse:0.02878
# [288]	validation_0-rmse:0.02405	validation_1-rmse:0.02864
# [289]	validation_0-rmse:0.02402	validation_1-rmse:0.02850
# [290]	validation_0-rmse:0.02399	validation_1-rmse:0.02835
# [291]	validation_0-rmse:0.02396	validation_1-rmse:0.02824
# [292]	validation_0-rmse:0.02393	validation_1-rmse:0.02807
# [293]	validation_0-rmse:0.02390	validation_1-rmse:0.02793
# [294]	validation_0-rmse:0.02387	validation_1-rmse:0.02778
# [295]	validation_0-rmse:0.02384	validation_1-rmse:0.02760
# [296]	validation_0-rmse:0.02381	validation_1-rmse:0.02745
# [297]	validation_0-rmse:0.02378	validation_1-rmse:0.02730
# [298]	validation_0-rmse:0.02375	validation_1-rmse:0.02718
# [299]	validation_0-rmse:0.02373	validation_1-rmse:0.02707
# [300]	validation_0-rmse:0.02370	validation_1-rmse:0.02694
# [301]	validation_0-rmse:0.02367	validation_1-rmse:0.02680
# [302]	validation_0-rmse:0.02365	validation_1-rmse:0.02671
# [303]	validation_0-rmse:0.02362	validation_1-rmse:0.02658
# [304]	validation_0-rmse:0.02360	validation_1-rmse:0.02647
# [305]	validation_0-rmse:0.02357	validation_1-rmse:0.02638
# [306]	validation_0-rmse:0.02355	validation_1-rmse:0.02627
# [307]	validation_0-rmse:0.02352	validation_1-rmse:0.02613
# [308]	validation_0-rmse:0.02350	validation_1-rmse:0.02601
# [309]	validation_0-rmse:0.02347	validation_1-rmse:0.02592
# [310]	validation_0-rmse:0.02345	validation_1-rmse:0.02580
# [311]	validation_0-rmse:0.02342	validation_1-rmse:0.02573
# [312]	validation_0-rmse:0.02340	validation_1-rmse:0.02562
# [313]	validation_0-rmse:0.02338	validation_1-rmse:0.02552
# [314]	validation_0-rmse:0.02335	validation_1-rmse:0.02542
# [315]	validation_0-rmse:0.02333	validation_1-rmse:0.02532
# [316]	validation_0-rmse:0.02331	validation_1-rmse:0.02522
# [317]	validation_0-rmse:0.02328	validation_1-rmse:0.02514
# [318]	validation_0-rmse:0.02326	validation_1-rmse:0.02504
# [319]	validation_0-rmse:0.02324	validation_1-rmse:0.02494
# [320]	validation_0-rmse:0.02322	validation_1-rmse:0.02484
# [321]	validation_0-rmse:0.02320	validation_1-rmse:0.02475
# [322]	validation_0-rmse:0.02318	validation_1-rmse:0.02465
# [323]	validation_0-rmse:0.02315	validation_1-rmse:0.02457
# [324]	validation_0-rmse:0.02314	validation_1-rmse:0.02450
# [325]	validation_0-rmse:0.02312	validation_1-rmse:0.02441
# [326]	validation_0-rmse:0.02309	validation_1-rmse:0.02434
# [327]	validation_0-rmse:0.02308	validation_1-rmse:0.02427
# [328]	validation_0-rmse:0.02306	validation_1-rmse:0.02417
# [329]	validation_0-rmse:0.02304	validation_1-rmse:0.02407
# [330]	validation_0-rmse:0.02302	validation_1-rmse:0.02400
# [331]	validation_0-rmse:0.02300	validation_1-rmse:0.02392
# [332]	validation_0-rmse:0.02298	validation_1-rmse:0.02382
# [333]	validation_0-rmse:0.02296	validation_1-rmse:0.02373
# [334]	validation_0-rmse:0.02294	validation_1-rmse:0.02372
# [335]	validation_0-rmse:0.02292	validation_1-rmse:0.02363
# [336]	validation_0-rmse:0.02290	validation_1-rmse:0.02355
# [337]	validation_0-rmse:0.02288	validation_1-rmse:0.02346
# [338]	validation_0-rmse:0.02287	validation_1-rmse:0.02341
# [339]	validation_0-rmse:0.02285	validation_1-rmse:0.02333
# [340]	validation_0-rmse:0.02283	validation_1-rmse:0.02325
# [341]	validation_0-rmse:0.02281	validation_1-rmse:0.02319
# [342]	validation_0-rmse:0.02280	validation_1-rmse:0.02313
# [343]	validation_0-rmse:0.02278	validation_1-rmse:0.02303
# [344]	validation_0-rmse:0.02276	validation_1-rmse:0.02295
# [345]	validation_0-rmse:0.02275	validation_1-rmse:0.02288
# [346]	validation_0-rmse:0.02273	validation_1-rmse:0.02281
# [347]	validation_0-rmse:0.02272	validation_1-rmse:0.02273
# [348]	validation_0-rmse:0.02270	validation_1-rmse:0.02262
# [349]	validation_0-rmse:0.02269	validation_1-rmse:0.02252
# [350]	validation_0-rmse:0.02267	validation_1-rmse:0.02243
# [351]	validation_0-rmse:0.02265	validation_1-rmse:0.02238
# [352]	validation_0-rmse:0.02264	validation_1-rmse:0.02229
# [353]	validation_0-rmse:0.02262	validation_1-rmse:0.02222
# [354]	validation_0-rmse:0.02261	validation_1-rmse:0.02215
# [355]	validation_0-rmse:0.02259	validation_1-rmse:0.02207
# [356]	validation_0-rmse:0.02258	validation_1-rmse:0.02197
# [357]	validation_0-rmse:0.02256	validation_1-rmse:0.02189
# [358]	validation_0-rmse:0.02255	validation_1-rmse:0.02180
# [359]	validation_0-rmse:0.02254	validation_1-rmse:0.02172
# [360]	validation_0-rmse:0.02252	validation_1-rmse:0.02165
# [361]	validation_0-rmse:0.02250	validation_1-rmse:0.02156
# [362]	validation_0-rmse:0.02249	validation_1-rmse:0.02152
# [363]	validation_0-rmse:0.02248	validation_1-rmse:0.02146
# [364]	validation_0-rmse:0.02247	validation_1-rmse:0.02141
# [365]	validation_0-rmse:0.02245	validation_1-rmse:0.02136
# [366]	validation_0-rmse:0.02244	validation_1-rmse:0.02129
# [367]	validation_0-rmse:0.02243	validation_1-rmse:0.02120
# [368]	validation_0-rmse:0.02242	validation_1-rmse:0.02114
# [369]	validation_0-rmse:0.02240	validation_1-rmse:0.02110
# [370]	validation_0-rmse:0.02239	validation_1-rmse:0.02103
# [371]	validation_0-rmse:0.02238	validation_1-rmse:0.02097
# [372]	validation_0-rmse:0.02237	validation_1-rmse:0.02094
# [373]	validation_0-rmse:0.02236	validation_1-rmse:0.02088
# [374]	validation_0-rmse:0.02235	validation_1-rmse:0.02079
# [375]	validation_0-rmse:0.02233	validation_1-rmse:0.02076
# [376]	validation_0-rmse:0.02232	validation_1-rmse:0.02070
# [377]	validation_0-rmse:0.02231	validation_1-rmse:0.02065
# [378]	validation_0-rmse:0.02229	validation_1-rmse:0.02060
# [379]	validation_0-rmse:0.02228	validation_1-rmse:0.02056
# [380]	validation_0-rmse:0.02227	validation_1-rmse:0.02052
# [381]	validation_0-rmse:0.02226	validation_1-rmse:0.02044
# [382]	validation_0-rmse:0.02225	validation_1-rmse:0.02041
# [383]	validation_0-rmse:0.02224	validation_1-rmse:0.02034
# [384]	validation_0-rmse:0.02223	validation_1-rmse:0.02026
# [385]	validation_0-rmse:0.02222	validation_1-rmse:0.02023
# [386]	validation_0-rmse:0.02221	validation_1-rmse:0.02019
# [387]	validation_0-rmse:0.02220	validation_1-rmse:0.02014
# [388]	validation_0-rmse:0.02218	validation_1-rmse:0.02011
# [389]	validation_0-rmse:0.02217	validation_1-rmse:0.02007
# [390]	validation_0-rmse:0.02216	validation_1-rmse:0.02001
# [391]	validation_0-rmse:0.02216	validation_1-rmse:0.01994
# [392]	validation_0-rmse:0.02215	validation_1-rmse:0.01988
# [393]	validation_0-rmse:0.02214	validation_1-rmse:0.01985
# [394]	validation_0-rmse:0.02213	validation_1-rmse:0.01982
# [395]	validation_0-rmse:0.02212	validation_1-rmse:0.01978
# [396]	validation_0-rmse:0.02211	validation_1-rmse:0.01974
# [397]	validation_0-rmse:0.02210	validation_1-rmse:0.01970
# [398]	validation_0-rmse:0.02209	validation_1-rmse:0.01965
# [399]	validation_0-rmse:0.02208	validation_1-rmse:0.01960
# [400]	validation_0-rmse:0.02207	validation_1-rmse:0.01956
# [401]	validation_0-rmse:0.02206	validation_1-rmse:0.01953
# [402]	validation_0-rmse:0.02205	validation_1-rmse:0.01950
# [403]	validation_0-rmse:0.02204	validation_1-rmse:0.01947
# [404]	validation_0-rmse:0.02203	validation_1-rmse:0.01944
# [405]	validation_0-rmse:0.02202	validation_1-rmse:0.01938
# [406]	validation_0-rmse:0.02201	validation_1-rmse:0.01932
# [407]	validation_0-rmse:0.02200	validation_1-rmse:0.01928
# [408]	validation_0-rmse:0.02199	validation_1-rmse:0.01923
# [409]	validation_0-rmse:0.02198	validation_1-rmse:0.01919
# [410]	validation_0-rmse:0.02197	validation_1-rmse:0.01917
# [411]	validation_0-rmse:0.02196	validation_1-rmse:0.01914
# [412]	validation_0-rmse:0.02195	validation_1-rmse:0.01911
# [413]	validation_0-rmse:0.02194	validation_1-rmse:0.01908
# [414]	validation_0-rmse:0.02193	validation_1-rmse:0.01906
# [415]	validation_0-rmse:0.02192	validation_1-rmse:0.01902
# [416]	validation_0-rmse:0.02191	validation_1-rmse:0.01899
# [417]	validation_0-rmse:0.02191	validation_1-rmse:0.01897
# [418]	validation_0-rmse:0.02190	validation_1-rmse:0.01895
# [419]	validation_0-rmse:0.02189	validation_1-rmse:0.01891
# [420]	validation_0-rmse:0.02188	validation_1-rmse:0.01888
# [421]	validation_0-rmse:0.02187	validation_1-rmse:0.01884
# [422]	validation_0-rmse:0.02186	validation_1-rmse:0.01881
# [423]	validation_0-rmse:0.02185	validation_1-rmse:0.01879
# [424]	validation_0-rmse:0.02185	validation_1-rmse:0.01877
# [425]	validation_0-rmse:0.02184	validation_1-rmse:0.01874
# [426]	validation_0-rmse:0.02183	validation_1-rmse:0.01872
# [427]	validation_0-rmse:0.02182	validation_1-rmse:0.01870
# [428]	validation_0-rmse:0.02181	validation_1-rmse:0.01868
# [429]	validation_0-rmse:0.02180	validation_1-rmse:0.01863
# [430]	validation_0-rmse:0.02180	validation_1-rmse:0.01860
# [431]	validation_0-rmse:0.02179	validation_1-rmse:0.01857
# [432]	validation_0-rmse:0.02178	validation_1-rmse:0.01853
# [433]	validation_0-rmse:0.02177	validation_1-rmse:0.01851
# [434]	validation_0-rmse:0.02177	validation_1-rmse:0.01848
# [435]	validation_0-rmse:0.02176	validation_1-rmse:0.01845
# [436]	validation_0-rmse:0.02175	validation_1-rmse:0.01842
# [437]	validation_0-rmse:0.02174	validation_1-rmse:0.01839
# [438]	validation_0-rmse:0.02174	validation_1-rmse:0.01834
# [439]	validation_0-rmse:0.02173	validation_1-rmse:0.01831
# [440]	validation_0-rmse:0.02172	validation_1-rmse:0.01826
# [441]	validation_0-rmse:0.02171	validation_1-rmse:0.01823
# [442]	validation_0-rmse:0.02170	validation_1-rmse:0.01816
# [443]	validation_0-rmse:0.02170	validation_1-rmse:0.01813
# [444]	validation_0-rmse:0.02169	validation_1-rmse:0.01811
# [445]	validation_0-rmse:0.02168	validation_1-rmse:0.01809
# [446]	validation_0-rmse:0.02168	validation_1-rmse:0.01807
# [447]	validation_0-rmse:0.02167	validation_1-rmse:0.01804
# [448]	validation_0-rmse:0.02166	validation_1-rmse:0.01803
# [449]	validation_0-rmse:0.02165	validation_1-rmse:0.01800
# [450]	validation_0-rmse:0.02164	validation_1-rmse:0.01798
# [451]	validation_0-rmse:0.02164	validation_1-rmse:0.01798
# [452]	validation_0-rmse:0.02163	validation_1-rmse:0.01796
# [453]	validation_0-rmse:0.02162	validation_1-rmse:0.01795
# [454]	validation_0-rmse:0.02161	validation_1-rmse:0.01791
# [455]	validation_0-rmse:0.02160	validation_1-rmse:0.01790
# [456]	validation_0-rmse:0.02160	validation_1-rmse:0.01789
# [457]	validation_0-rmse:0.02159	validation_1-rmse:0.01786
# [458]	validation_0-rmse:0.02158	validation_1-rmse:0.01785
# [459]	validation_0-rmse:0.02157	validation_1-rmse:0.01800
# [460]	validation_0-rmse:0.02156	validation_1-rmse:0.01798
# [461]	validation_0-rmse:0.02156	validation_1-rmse:0.01795
# [462]	validation_0-rmse:0.02155	validation_1-rmse:0.01794
# [463]	validation_0-rmse:0.02154	validation_1-rmse:0.01792
# [464]	validation_0-rmse:0.02154	validation_1-rmse:0.01791
# [465]	validation_0-rmse:0.02153	validation_1-rmse:0.01790
# [466]	validation_0-rmse:0.02153	validation_1-rmse:0.01787
# [467]	validation_0-rmse:0.02152	validation_1-rmse:0.01784
# [468]	validation_0-rmse:0.02151	validation_1-rmse:0.01787
# [469]	validation_0-rmse:0.02151	validation_1-rmse:0.01786
# [470]	validation_0-rmse:0.02150	validation_1-rmse:0.01784
# [471]	validation_0-rmse:0.02149	validation_1-rmse:0.01783
# [472]	validation_0-rmse:0.02149	validation_1-rmse:0.01780
# [473]	validation_0-rmse:0.02148	validation_1-rmse:0.01777
# [474]	validation_0-rmse:0.02147	validation_1-rmse:0.01776
# [475]	validation_0-rmse:0.02147	validation_1-rmse:0.01775
# [476]	validation_0-rmse:0.02146	validation_1-rmse:0.01774
# [477]	validation_0-rmse:0.02146	validation_1-rmse:0.01773
# [478]	validation_0-rmse:0.02145	validation_1-rmse:0.01772
# [479]	validation_0-rmse:0.02144	validation_1-rmse:0.01767
# [480]	validation_0-rmse:0.02144	validation_1-rmse:0.01764
# [481]	validation_0-rmse:0.02143	validation_1-rmse:0.01763
# [482]	validation_0-rmse:0.02142	validation_1-rmse:0.01761
# [483]	validation_0-rmse:0.02142	validation_1-rmse:0.01757
# [484]	validation_0-rmse:0.02141	validation_1-rmse:0.01756
# [485]	validation_0-rmse:0.02141	validation_1-rmse:0.01754
# [486]	validation_0-rmse:0.02140	validation_1-rmse:0.01750
# [487]	validation_0-rmse:0.02140	validation_1-rmse:0.01748
# [488]	validation_0-rmse:0.02139	validation_1-rmse:0.01747
# [489]	validation_0-rmse:0.02139	validation_1-rmse:0.01746
# [490]	validation_0-rmse:0.02138	validation_1-rmse:0.01741
# [491]	validation_0-rmse:0.02138	validation_1-rmse:0.01738
# [492]	validation_0-rmse:0.02137	validation_1-rmse:0.01736
# [493]	validation_0-rmse:0.02137	validation_1-rmse:0.01734
# [494]	validation_0-rmse:0.02136	validation_1-rmse:0.01732
# [495]	validation_0-rmse:0.02136	validation_1-rmse:0.01730
# [496]	validation_0-rmse:0.02135	validation_1-rmse:0.01725
# [497]	validation_0-rmse:0.02135	validation_1-rmse:0.01724
# [498]	validation_0-rmse:0.02134	validation_1-rmse:0.01723
# [499]	validation_0-rmse:0.02134	validation_1-rmse:0.01721
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
results = xgb_model.evals_result()

# %%
train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("RMSE Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 2 Days Prediction

# %%
y_pred2 = xgb_model.predict(X_test2)

# %%
y_pred2
# Out:
# array([0.81587714, 0.7875067 , 0.7656307 , 0.7617996 , 0.74923444,
#        0.7431988 , 0.73008406, 0.7108009 , 0.7025454 , 0.69939375,
#        0.6835131 , 0.711974  , 0.73726916, 0.7549985 , 0.76246005,
#        0.7575746 , 0.7402164 , 0.72963005, 0.73235774, 0.75572187,
#        0.81723595, 0.82283866, 0.82048136, 0.81109464], dtype=float32)

# %%
y_test2_original = scaler.inverse_transform(y_test2)
y_pred2_original = scaler.inverse_transform([y_pred2])

# %%
y_pred2_original.shape
# Out:
# (1, 24)

# %%
y_pred2_original = y_pred2_original.reshape(y_pred2_original.shape[1], y_pred2_original.shape[0])

# %%
print(y_pred2_original.shape)
# Out:
# (24, 1)

# %%
rmse = np.sqrt(mean_squared_error(y_test2_original, y_pred2_original))
mse = mean_squared_error(y_test2_original, y_pred2_original) 
mape = mean_absolute_percentage_error(y_test2_original, y_pred2_original)
r2 = r2_score(y_test2_original, y_pred2_original)

# %%
print(f" RMSE:{rmse},\n MSE:{mse},\n MAPE:{mape*100}%,\n R-Squared:{r2}")
# Out:
#  RMSE:240.64584541004842,
#  MSE:57910.42291311693,
#  MAPE:1.307260328237133%,
#  R-Squared:0.8716617152169777

# %%
import matplotlib.pyplot as plt

# Plot Actual vs Predicted Demand
plt.figure(figsize=(12, 6))
plt.plot(y_test2_original.flatten(), label='Actual Demand', color='blue', alpha=0.7)
plt.plot(y_pred2_original.flatten(), label='Predicted Demand', color='orange', alpha=0.7)
plt.title('Actual vs Predicted Demand')
plt.xlabel('Time Steps')
plt.ylabel('Demand (MW)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7 days prediction

# %%
y_pred7 = xgb_model.predict(X_test7)

# %%
y_pred7_original = scaler.inverse_transform([y_pred7])
y_test7_original = scaler.inverse_transform(y_test7)

# %%
y_pred7_original = y_pred7_original.reshape(y_pred7_original.shape[1], y_pred7_original.shape[0])

# %%
rmse = np.sqrt(mean_squared_error(y_test7_original, y_pred7_original))
mse = mean_squared_error(y_test7_original, y_pred7_original) 
mape = mean_absolute_percentage_error(y_test7_original, y_pred7_original)
r2 = r2_score(y_test7_original, y_pred7_original)

# %%
print(f" RMSE:{rmse},\n MSE:{mse},\n MAPE:{mape*100}%,\n R-Squared:{r2}")
# Out:
#  RMSE:426.41900278980063,
#  MSE:181833.165940248,
#  MAPE:2.243844850909355%,
#  R-Squared:0.8843297591692303

# %%
import matplotlib.pyplot as plt

# Plot Actual vs Predicted Demand
plt.figure(figsize=(12, 6))
plt.plot(y_test7_original.flatten(), label='Actual Demand', color='blue', alpha=0.7)
plt.plot(y_pred7_original.flatten(), label='Predicted Demand', color='orange', alpha=0.7)
plt.title('Actual vs Predicted Demand')
plt.xlabel('Time Steps')
plt.ylabel('Demand (MW)')
plt.legend()
plt.grid(True)
plt.show()

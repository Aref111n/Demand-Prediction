# %%
import pandas as pd

file_path = '/kaggle/input/demand/reversed_finaldatacsv.xlsx'

df = pd.read_excel(file_path)
df.head()
# Out:
#               Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  Coal
# 0  01-01-2016 08:00:00          4140.0        4140  3734          113     0
# 1  01-01-2016 09:00:00          3941.0        3941  3551          113     0
# 2  01-01-2016 10:00:00          3724.0        3724  3286          133     0
# 3  01-01-2016 11:00:00          3603.0        3603  3168          130     0
# 4  01-01-2016 12:00:00          3590.0        3590  3145          140     0

# %%
df['Datetime_formatted'] = pd.to_datetime(df['Datetime'], format='%d-%m-%Y %H:%M:%S')

# %%
df
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 0      01-01-2016 08:00:00          4140.0        4140  3734          113
# 1      01-01-2016 09:00:00          3941.0        3941  3551          113
# 2      01-01-2016 10:00:00          3724.0        3724  3286          133
# 3      01-01-2016 11:00:00          3603.0        3603  3168          130
# 4      01-01-2016 12:00:00          3590.0        3590  3145          140
# ...                    ...             ...         ...   ...          ...
# 70464  15-01-2024 08:00:00          8619.0        8619  4331          866
# 70465  15-01-2024 09:00:00          9018.0        9018  4224         1202
# 70466  15-01-2024 10:00:00          9162.0        9162  4223         1300
# 70467  15-01-2024 11:00:00          9211.0        9211  4101         1427
# 70468  15-01-2024 12:00:00          9335.0        9335  4133         1428
#
#        Coal  Datetime_formatted
# 0         0 2016-01-01 08:00:00
# 1         0 2016-01-01 09:00:00
# 2         0 2016-01-01 10:00:00
# 3         0 2016-01-01 11:00:00
# 4         0 2016-01-01 12:00:00
# ...     ...                 ...
# 70464  2434 2024-01-15 08:00:00
# 70465  2572 2024-01-15 09:00:00
# 70466  2573 2024-01-15 10:00:00
# 70467  2567 2024-01-15 11:00:00
# 70468  2566 2024-01-15 12:00:00
#
# [70469 rows x 7 columns]

# %%
daily_counts = df.groupby(df['Datetime_formatted'].dt.date).size()
daily_counts
# Out:
# Datetime_formatted
# 2016-01-01    16
# 2016-01-02    24
# 2016-01-03    24
# 2016-01-04    24
# 2016-01-05    24
#               ..
# 2024-01-11    24
# 2024-01-12    24
# 2024-01-13    24
# 2024-01-14    24
# 2024-01-15    13
# Length: 2937, dtype: int64

# %%
num_days_with_24_entries = (daily_counts == 24).sum()
num_days_with_24_entries
# Out:
# 2935

# %%
dates_to_keep = daily_counts[daily_counts == 24].index
df_filtered = df[df['Datetime_formatted'].dt.date.isin(dates_to_keep)]
df_filtered
# Out:
#                   Datetime  Generation(MW)  Demand(MW)   Gas  Liquid Fuel  \
# 16     02-01-2016 00:00:00          3737.0        3737  3269          123
# 17     02-01-2016 01:00:00          4023.0        4023  3312          198
# 18     02-01-2016 02:00:00          5606.0        5606  3786         1313
# 19     02-01-2016 03:00:00          5847.0        5847  4235         1099
# 20     02-01-2016 04:00:00          5880.0        5880  4287         1080
# ...                    ...             ...         ...   ...          ...
# 70451  14-01-2024 19:00:00         10209.0       10209  4240         2459
# 70452  14-01-2024 20:00:00         10289.0       10289  4369         2391
# 70453  14-01-2024 21:00:00         10004.0       10004  4421         2099
# 70454  14-01-2024 22:00:00          9560.0        9560  4237         1864
# 70455  14-01-2024 23:00:00          8793.0        8793  4192         1168
#
#        Coal  Datetime_formatted
# 16        0 2016-01-02 00:00:00
# 17        0 2016-01-02 01:00:00
# 18        0 2016-01-02 02:00:00
# 19        0 2016-01-02 03:00:00
# 20        0 2016-01-02 04:00:00
# ...     ...                 ...
# 70451  2464 2024-01-14 19:00:00
# 70452  2513 2024-01-14 20:00:00
# 70453  2406 2024-01-14 21:00:00
# 70454  2381 2024-01-14 22:00:00
# 70455  2355 2024-01-14 23:00:00
#
# [70440 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)
# Out:
# <ipython-input-10-1d42b4394300>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Demand(MW)'] = df_filtered['Demand(MW)'].clip(upper=18000)

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df_filtered['Demand(MW)'])
plt.title('Boxplot of Demand(MW)')
plt.xlabel('Values')

plt.show()

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# %%
demand_data = df_filtered['Demand(MW)'].values

# %%
demand_data
# Out:
# array([ 3737,  4023,  5606, ..., 10004,  9560,  8793])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(demand_data.reshape(-1, 1))
data_scaled
# Out:
# array([[0.20734689],
#        [0.22324108],
#        [0.31121485],
#        ...,
#        [0.55562965],
#        [0.53095476],
#        [0.48832944]])

# %%
train_samples = 2800 * 24
val_samples = 2 * 24
test2_samples = 2 * 24
test7_samples = 7 * 24
look_back = 24

# %%
def create_dataset(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i + look_back])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

# %%
train_data = data_scaled[:train_samples]  
val_data = data_scaled[train_samples:train_samples + val_samples]  
test2_data = data_scaled[train_samples + val_samples:train_samples + val_samples + test2_samples] 
test7_data = data_scaled[train_samples + val_samples + test2_samples:train_samples + val_samples + test2_samples + test7_samples]

# %%
X_train, y_train = create_dataset(train_data, look_back)
X_test2, y_test2 = create_dataset(test2_data, look_back)
X_test7, y_test7 = create_dataset(test7_data, look_back)
X_val, y_val = create_dataset(val_data, look_back)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1])
X_test2 = X_test2.reshape(X_test2.shape[0], X_test2.shape[1])
X_test7 = X_test7.reshape(X_test7.shape[0], X_test7.shape[1])
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1])

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_val_score

# %%
class GWO:
    def __init__(self, obj_func, dim, bounds, num_wolves=5, max_iter=20):
        self.obj_func = obj_func
        self.dim = dim
        self.bounds = np.array(bounds)
        self.num_wolves = num_wolves
        self.max_iter = max_iter
        
        self.alpha, self.beta, self.delta = None, None, None
        self.alpha_score, self.beta_score, self.delta_score = float('inf'), float('inf'), float('inf')
        
        self.wolves = np.random.uniform(self.bounds[:, 0], self.bounds[:, 1], (self.num_wolves, self.dim))
        
    def optimize(self):
        for t in range(self.max_iter):
            for i in range(self.num_wolves):
                fitness = self.obj_func(self.wolves[i])
                
                if fitness < self.alpha_score:
                    self.delta, self.delta_score = self.beta, self.beta_score
                    self.beta, self.beta_score = self.alpha, self.alpha_score
                    self.alpha, self.alpha_score = self.wolves[i], fitness
                elif fitness < self.beta_score:
                    self.delta, self.delta_score = self.beta, self.beta_score
                    self.beta, self.beta_score = self.wolves[i], fitness
                elif fitness < self.delta_score:
                    self.delta, self.delta_score = self.wolves[i], fitness
                
            a = 2 - t * (2 / self.max_iter)
            
            for i in range(self.num_wolves):
                for j in range(self.dim):
                    A1, A2, A3 = a * (2 * np.random.rand() - 1), a * (2 * np.random.rand() - 1), a * (2 * np.random.rand() - 1)
                    C1, C2, C3 = 2 * np.random.rand(), 2 * np.random.rand(), 2 * np.random.rand()
                    
                    D_alpha = abs(C1 * self.alpha[j] - self.wolves[i][j])
                    D_beta = abs(C2 * self.beta[j] - self.wolves[i][j])
                    D_delta = abs(C3 * self.delta[j] - self.wolves[i][j])
                    
                    X1 = self.alpha[j] - A1 * D_alpha
                    X2 = self.beta[j] - A2 * D_beta
                    X3 = self.delta[j] - A3 * D_delta
                    
                    self.wolves[i][j] = np.clip((X1 + X2 + X3) / 3, self.bounds[j, 0], self.bounds[j, 1])
        
        return self.alpha, self.alpha_score

# %%
from sklearn.metrics import mean_squared_error
def xgb_objective(params):
    params = {
        'max_depth': int(params[0]),
        'learning_rate': params[1],
        'n_estimators': int(params[2]),
        'subsample': params[3],
        'colsample_bytree': params[4]
    }
    model = xgb.XGBRegressor(**params, objective='reg:squarederror')
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_root_mean_squared_error')
    return -np.mean(scores)

# %%
bounds = [(3, 10), (0.01, 0.3), (50, 300), (0.5, 1.0), (0.5, 1.0)]

# %%
gwo = GWO(obj_func=xgb_objective, dim=5, bounds=bounds, num_wolves=5, max_iter=20)
best_params, best_score = gwo.optimize()

# %%
best_params = {
    'max_depth': int(best_params[0]),
    'learning_rate': best_params[1],
    'n_estimators': int(best_params[2]),
    'subsample': best_params[3],
    'colsample_bytree': best_params[4]
}

# %%
best_params
# Out:
# {'max_depth': 9,
#  'learning_rate': 0.011827896600947194,
#  'n_estimators': 256,
#  'subsample': 0.5645633348508898,
#  'colsample_bytree': 0.9421561675144147}

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=256,  
    learning_rate=0.011827896600947194,  
    max_depth=9,  
    subsample=0.5645633348508898,  
    colsample_bytree=0.9421561675144147,  
    reg_lambda=0.1, 
    reg_alpha=0.1, 
    objective='reg:squarederror',
    random_state=42
)

# %%
evals_result = {}

# Train the model while tracking loss
xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],  # Track both train and val loss
    eval_metric='rmse',  # Root Mean Squared Error (RMSE) as the metric
    early_stopping_rounds=10,
    verbose=True
)
# Out:
# [0]	validation_0-rmse:0.12680	validation_1-rmse:0.27955
# [1]	validation_0-rmse:0.12536	validation_1-rmse:0.27639
# [2]	validation_0-rmse:0.12398	validation_1-rmse:0.27329
# [3]	validation_0-rmse:0.12260	validation_1-rmse:0.27024
# [4]	validation_0-rmse:0.12121	validation_1-rmse:0.26720
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.11984	validation_1-rmse:0.26416
# [6]	validation_0-rmse:0.11848	validation_1-rmse:0.26115
# [7]	validation_0-rmse:0.11714	validation_1-rmse:0.25817
# [8]	validation_0-rmse:0.11582	validation_1-rmse:0.25526
# [9]	validation_0-rmse:0.11451	validation_1-rmse:0.25236
# [10]	validation_0-rmse:0.11322	validation_1-rmse:0.24950
# [11]	validation_0-rmse:0.11194	validation_1-rmse:0.24667
# [12]	validation_0-rmse:0.11068	validation_1-rmse:0.24389
# [13]	validation_0-rmse:0.10944	validation_1-rmse:0.24112
# [14]	validation_0-rmse:0.10821	validation_1-rmse:0.23848
# [15]	validation_0-rmse:0.10700	validation_1-rmse:0.23579
# [16]	validation_0-rmse:0.10580	validation_1-rmse:0.23308
# [17]	validation_0-rmse:0.10461	validation_1-rmse:0.23046
# [18]	validation_0-rmse:0.10344	validation_1-rmse:0.22784
# [19]	validation_0-rmse:0.10228	validation_1-rmse:0.22525
# [20]	validation_0-rmse:0.10114	validation_1-rmse:0.22268
# [21]	validation_0-rmse:0.10001	validation_1-rmse:0.22017
# [22]	validation_0-rmse:0.09890	validation_1-rmse:0.21778
# [23]	validation_0-rmse:0.09780	validation_1-rmse:0.21534
# [24]	validation_0-rmse:0.09671	validation_1-rmse:0.21299
# [25]	validation_0-rmse:0.09563	validation_1-rmse:0.21058
# [26]	validation_0-rmse:0.09460	validation_1-rmse:0.20832
# [27]	validation_0-rmse:0.09355	validation_1-rmse:0.20599
# [28]	validation_0-rmse:0.09254	validation_1-rmse:0.20371
# [29]	validation_0-rmse:0.09151	validation_1-rmse:0.20143
# [30]	validation_0-rmse:0.09050	validation_1-rmse:0.19916
# [31]	validation_0-rmse:0.08950	validation_1-rmse:0.19694
# [32]	validation_0-rmse:0.08852	validation_1-rmse:0.19472
# [33]	validation_0-rmse:0.08754	validation_1-rmse:0.19257
# [34]	validation_0-rmse:0.08658	validation_1-rmse:0.19041
# [35]	validation_0-rmse:0.08563	validation_1-rmse:0.18826
# [36]	validation_0-rmse:0.08472	validation_1-rmse:0.18618
# [37]	validation_0-rmse:0.08379	validation_1-rmse:0.18409
# [38]	validation_0-rmse:0.08287	validation_1-rmse:0.18201
# [39]	validation_0-rmse:0.08197	validation_1-rmse:0.17999
# [40]	validation_0-rmse:0.08108	validation_1-rmse:0.17797
# [41]	validation_0-rmse:0.08019	validation_1-rmse:0.17609
# [42]	validation_0-rmse:0.07932	validation_1-rmse:0.17414
# [43]	validation_0-rmse:0.07846	validation_1-rmse:0.17225
# [44]	validation_0-rmse:0.07761	validation_1-rmse:0.17030
# [45]	validation_0-rmse:0.07678	validation_1-rmse:0.16841
# [46]	validation_0-rmse:0.07594	validation_1-rmse:0.16646
# [47]	validation_0-rmse:0.07513	validation_1-rmse:0.16461
# [48]	validation_0-rmse:0.07432	validation_1-rmse:0.16275
# [49]	validation_0-rmse:0.07351	validation_1-rmse:0.16092
# [50]	validation_0-rmse:0.07275	validation_1-rmse:0.15916
# [51]	validation_0-rmse:0.07197	validation_1-rmse:0.15749
# [52]	validation_0-rmse:0.07120	validation_1-rmse:0.15575
# [53]	validation_0-rmse:0.07044	validation_1-rmse:0.15402
# [54]	validation_0-rmse:0.06969	validation_1-rmse:0.15232
# [55]	validation_0-rmse:0.06895	validation_1-rmse:0.15062
# [56]	validation_0-rmse:0.06822	validation_1-rmse:0.14894
# [57]	validation_0-rmse:0.06750	validation_1-rmse:0.14762
# [58]	validation_0-rmse:0.06679	validation_1-rmse:0.14600
# [59]	validation_0-rmse:0.06608	validation_1-rmse:0.14444
# [60]	validation_0-rmse:0.06539	validation_1-rmse:0.14285
# [61]	validation_0-rmse:0.06470	validation_1-rmse:0.14125
# [62]	validation_0-rmse:0.06402	validation_1-rmse:0.13968
# [63]	validation_0-rmse:0.06335	validation_1-rmse:0.13813
# [64]	validation_0-rmse:0.06271	validation_1-rmse:0.13668
# [65]	validation_0-rmse:0.06206	validation_1-rmse:0.13518
# [66]	validation_0-rmse:0.06141	validation_1-rmse:0.13399
# [67]	validation_0-rmse:0.06080	validation_1-rmse:0.13257
# [68]	validation_0-rmse:0.06017	validation_1-rmse:0.13115
# [69]	validation_0-rmse:0.05955	validation_1-rmse:0.12972
# [70]	validation_0-rmse:0.05893	validation_1-rmse:0.12827
# [71]	validation_0-rmse:0.05833	validation_1-rmse:0.12687
# [72]	validation_0-rmse:0.05773	validation_1-rmse:0.12549
# [73]	validation_0-rmse:0.05715	validation_1-rmse:0.12411
# [74]	validation_0-rmse:0.05656	validation_1-rmse:0.12277
# [75]	validation_0-rmse:0.05599	validation_1-rmse:0.12145
# [76]	validation_0-rmse:0.05543	validation_1-rmse:0.12017
# [77]	validation_0-rmse:0.05487	validation_1-rmse:0.11885
# [78]	validation_0-rmse:0.05433	validation_1-rmse:0.11762
# [79]	validation_0-rmse:0.05379	validation_1-rmse:0.11634
# [80]	validation_0-rmse:0.05325	validation_1-rmse:0.11508
# [81]	validation_0-rmse:0.05272	validation_1-rmse:0.11383
# [82]	validation_0-rmse:0.05219	validation_1-rmse:0.11259
# [83]	validation_0-rmse:0.05167	validation_1-rmse:0.11143
# [84]	validation_0-rmse:0.05116	validation_1-rmse:0.11025
# [85]	validation_0-rmse:0.05066	validation_1-rmse:0.10907
# [86]	validation_0-rmse:0.05017	validation_1-rmse:0.10793
# [87]	validation_0-rmse:0.04968	validation_1-rmse:0.10680
# [88]	validation_0-rmse:0.04920	validation_1-rmse:0.10562
# [89]	validation_0-rmse:0.04872	validation_1-rmse:0.10450
# [90]	validation_0-rmse:0.04825	validation_1-rmse:0.10337
# [91]	validation_0-rmse:0.04778	validation_1-rmse:0.10228
# [92]	validation_0-rmse:0.04732	validation_1-rmse:0.10122
# [93]	validation_0-rmse:0.04688	validation_1-rmse:0.10021
# [94]	validation_0-rmse:0.04643	validation_1-rmse:0.09915
# [95]	validation_0-rmse:0.04599	validation_1-rmse:0.09807
# [96]	validation_0-rmse:0.04556	validation_1-rmse:0.09701
# [97]	validation_0-rmse:0.04513	validation_1-rmse:0.09600
# [98]	validation_0-rmse:0.04470	validation_1-rmse:0.09499
# [99]	validation_0-rmse:0.04428	validation_1-rmse:0.09398
# [100]	validation_0-rmse:0.04389	validation_1-rmse:0.09298
# [101]	validation_0-rmse:0.04348	validation_1-rmse:0.09198
# [102]	validation_0-rmse:0.04308	validation_1-rmse:0.09103
# [103]	validation_0-rmse:0.04268	validation_1-rmse:0.09009
# [104]	validation_0-rmse:0.04230	validation_1-rmse:0.08919
# [105]	validation_0-rmse:0.04191	validation_1-rmse:0.08825
# [106]	validation_0-rmse:0.04153	validation_1-rmse:0.08736
# [107]	validation_0-rmse:0.04115	validation_1-rmse:0.08645
# [108]	validation_0-rmse:0.04078	validation_1-rmse:0.08553
# [109]	validation_0-rmse:0.04043	validation_1-rmse:0.08483
# [110]	validation_0-rmse:0.04007	validation_1-rmse:0.08399
# [111]	validation_0-rmse:0.03971	validation_1-rmse:0.08310
# [112]	validation_0-rmse:0.03937	validation_1-rmse:0.08224
# [113]	validation_0-rmse:0.03902	validation_1-rmse:0.08137
# [114]	validation_0-rmse:0.03868	validation_1-rmse:0.08051
# [115]	validation_0-rmse:0.03834	validation_1-rmse:0.07967
# [116]	validation_0-rmse:0.03801	validation_1-rmse:0.07889
# [117]	validation_0-rmse:0.03769	validation_1-rmse:0.07811
# [118]	validation_0-rmse:0.03738	validation_1-rmse:0.07731
# [119]	validation_0-rmse:0.03706	validation_1-rmse:0.07654
# [120]	validation_0-rmse:0.03675	validation_1-rmse:0.07573
# [121]	validation_0-rmse:0.03645	validation_1-rmse:0.07496
# [122]	validation_0-rmse:0.03614	validation_1-rmse:0.07418
# [123]	validation_0-rmse:0.03584	validation_1-rmse:0.07342
# [124]	validation_0-rmse:0.03554	validation_1-rmse:0.07267
# [125]	validation_0-rmse:0.03525	validation_1-rmse:0.07191
# [126]	validation_0-rmse:0.03496	validation_1-rmse:0.07119
# [127]	validation_0-rmse:0.03468	validation_1-rmse:0.07045
# [128]	validation_0-rmse:0.03440	validation_1-rmse:0.06988
# [129]	validation_0-rmse:0.03412	validation_1-rmse:0.06919
# [130]	validation_0-rmse:0.03385	validation_1-rmse:0.06849
# [131]	validation_0-rmse:0.03358	validation_1-rmse:0.06787
# [132]	validation_0-rmse:0.03332	validation_1-rmse:0.06720
# [133]	validation_0-rmse:0.03306	validation_1-rmse:0.06656
# [134]	validation_0-rmse:0.03281	validation_1-rmse:0.06592
# [135]	validation_0-rmse:0.03257	validation_1-rmse:0.06533
# [136]	validation_0-rmse:0.03232	validation_1-rmse:0.06471
# [137]	validation_0-rmse:0.03208	validation_1-rmse:0.06406
# [138]	validation_0-rmse:0.03183	validation_1-rmse:0.06343
# [139]	validation_0-rmse:0.03159	validation_1-rmse:0.06282
# [140]	validation_0-rmse:0.03135	validation_1-rmse:0.06221
# [141]	validation_0-rmse:0.03112	validation_1-rmse:0.06160
# [142]	validation_0-rmse:0.03091	validation_1-rmse:0.06116
# [143]	validation_0-rmse:0.03068	validation_1-rmse:0.06062
# [144]	validation_0-rmse:0.03047	validation_1-rmse:0.06012
# [145]	validation_0-rmse:0.03025	validation_1-rmse:0.05962
# [146]	validation_0-rmse:0.03003	validation_1-rmse:0.05911
# [147]	validation_0-rmse:0.02982	validation_1-rmse:0.05854
# [148]	validation_0-rmse:0.02961	validation_1-rmse:0.05801
# [149]	validation_0-rmse:0.02941	validation_1-rmse:0.05745
# [150]	validation_0-rmse:0.02920	validation_1-rmse:0.05691
# [151]	validation_0-rmse:0.02900	validation_1-rmse:0.05638
# [152]	validation_0-rmse:0.02880	validation_1-rmse:0.05583
# [153]	validation_0-rmse:0.02861	validation_1-rmse:0.05528
# [154]	validation_0-rmse:0.02841	validation_1-rmse:0.05478
# [155]	validation_0-rmse:0.02823	validation_1-rmse:0.05424
# [156]	validation_0-rmse:0.02804	validation_1-rmse:0.05376
# [157]	validation_0-rmse:0.02786	validation_1-rmse:0.05324
# [158]	validation_0-rmse:0.02768	validation_1-rmse:0.05273
# [159]	validation_0-rmse:0.02750	validation_1-rmse:0.05223
# [160]	validation_0-rmse:0.02733	validation_1-rmse:0.05177
# [161]	validation_0-rmse:0.02716	validation_1-rmse:0.05131
# [162]	validation_0-rmse:0.02699	validation_1-rmse:0.05082
# [163]	validation_0-rmse:0.02682	validation_1-rmse:0.05034
# [164]	validation_0-rmse:0.02665	validation_1-rmse:0.04985
# [165]	validation_0-rmse:0.02650	validation_1-rmse:0.04940
# [166]	validation_0-rmse:0.02634	validation_1-rmse:0.04898
# [167]	validation_0-rmse:0.02618	validation_1-rmse:0.04850
# [168]	validation_0-rmse:0.02603	validation_1-rmse:0.04806
# [169]	validation_0-rmse:0.02588	validation_1-rmse:0.04763
# [170]	validation_0-rmse:0.02572	validation_1-rmse:0.04723
# [171]	validation_0-rmse:0.02558	validation_1-rmse:0.04683
# [172]	validation_0-rmse:0.02543	validation_1-rmse:0.04639
# [173]	validation_0-rmse:0.02530	validation_1-rmse:0.04612
# [174]	validation_0-rmse:0.02516	validation_1-rmse:0.04570
# [175]	validation_0-rmse:0.02502	validation_1-rmse:0.04528
# [176]	validation_0-rmse:0.02488	validation_1-rmse:0.04488
# [177]	validation_0-rmse:0.02475	validation_1-rmse:0.04448
# [178]	validation_0-rmse:0.02462	validation_1-rmse:0.04407
# [179]	validation_0-rmse:0.02449	validation_1-rmse:0.04370
# [180]	validation_0-rmse:0.02436	validation_1-rmse:0.04379
# [181]	validation_0-rmse:0.02423	validation_1-rmse:0.04342
# [182]	validation_0-rmse:0.02411	validation_1-rmse:0.04304
# [183]	validation_0-rmse:0.02398	validation_1-rmse:0.04268
# [184]	validation_0-rmse:0.02386	validation_1-rmse:0.04230
# [185]	validation_0-rmse:0.02374	validation_1-rmse:0.04195
# [186]	validation_0-rmse:0.02362	validation_1-rmse:0.04160
# [187]	validation_0-rmse:0.02351	validation_1-rmse:0.04125
# [188]	validation_0-rmse:0.02340	validation_1-rmse:0.04088
# [189]	validation_0-rmse:0.02329	validation_1-rmse:0.04057
# [190]	validation_0-rmse:0.02318	validation_1-rmse:0.04025
# [191]	validation_0-rmse:0.02307	validation_1-rmse:0.03988
# [192]	validation_0-rmse:0.02297	validation_1-rmse:0.03955
# [193]	validation_0-rmse:0.02287	validation_1-rmse:0.03927
# [194]	validation_0-rmse:0.02276	validation_1-rmse:0.03893
# [195]	validation_0-rmse:0.02266	validation_1-rmse:0.03862
# [196]	validation_0-rmse:0.02256	validation_1-rmse:0.03828
# [197]	validation_0-rmse:0.02247	validation_1-rmse:0.03795
# [198]	validation_0-rmse:0.02237	validation_1-rmse:0.03765
# [199]	validation_0-rmse:0.02228	validation_1-rmse:0.03734
# [200]	validation_0-rmse:0.02218	validation_1-rmse:0.03706
# [201]	validation_0-rmse:0.02209	validation_1-rmse:0.03673
# [202]	validation_0-rmse:0.02201	validation_1-rmse:0.03643
# [203]	validation_0-rmse:0.02192	validation_1-rmse:0.03616
# [204]	validation_0-rmse:0.02184	validation_1-rmse:0.03589
# [205]	validation_0-rmse:0.02175	validation_1-rmse:0.03564
# [206]	validation_0-rmse:0.02166	validation_1-rmse:0.03547
# [207]	validation_0-rmse:0.02158	validation_1-rmse:0.03522
# [208]	validation_0-rmse:0.02149	validation_1-rmse:0.03492
# [209]	validation_0-rmse:0.02142	validation_1-rmse:0.03466
# [210]	validation_0-rmse:0.02134	validation_1-rmse:0.03441
# [211]	validation_0-rmse:0.02126	validation_1-rmse:0.03417
# [212]	validation_0-rmse:0.02118	validation_1-rmse:0.03391
# [213]	validation_0-rmse:0.02111	validation_1-rmse:0.03366
# [214]	validation_0-rmse:0.02103	validation_1-rmse:0.03345
# [215]	validation_0-rmse:0.02096	validation_1-rmse:0.03331
# [216]	validation_0-rmse:0.02089	validation_1-rmse:0.03306
# [217]	validation_0-rmse:0.02082	validation_1-rmse:0.03282
# [218]	validation_0-rmse:0.02075	validation_1-rmse:0.03259
# [219]	validation_0-rmse:0.02068	validation_1-rmse:0.03236
# [220]	validation_0-rmse:0.02061	validation_1-rmse:0.03215
# [221]	validation_0-rmse:0.02055	validation_1-rmse:0.03195
# [222]	validation_0-rmse:0.02048	validation_1-rmse:0.03171
# [223]	validation_0-rmse:0.02042	validation_1-rmse:0.03145
# [224]	validation_0-rmse:0.02036	validation_1-rmse:0.03125
# [225]	validation_0-rmse:0.02029	validation_1-rmse:0.03108
# [226]	validation_0-rmse:0.02024	validation_1-rmse:0.03089
# [227]	validation_0-rmse:0.02017	validation_1-rmse:0.03066
# [228]	validation_0-rmse:0.02011	validation_1-rmse:0.03045
# [229]	validation_0-rmse:0.02006	validation_1-rmse:0.03033
# [230]	validation_0-rmse:0.02000	validation_1-rmse:0.03013
# [231]	validation_0-rmse:0.01994	validation_1-rmse:0.02995
# [232]	validation_0-rmse:0.01989	validation_1-rmse:0.02977
# [233]	validation_0-rmse:0.01983	validation_1-rmse:0.02958
# [234]	validation_0-rmse:0.01977	validation_1-rmse:0.02938
# [235]	validation_0-rmse:0.01972	validation_1-rmse:0.02919
# [236]	validation_0-rmse:0.01966	validation_1-rmse:0.02897
# [237]	validation_0-rmse:0.01961	validation_1-rmse:0.02880
# [238]	validation_0-rmse:0.01956	validation_1-rmse:0.02860
# [239]	validation_0-rmse:0.01951	validation_1-rmse:0.02842
# [240]	validation_0-rmse:0.01946	validation_1-rmse:0.02825
# [241]	validation_0-rmse:0.01941	validation_1-rmse:0.02805
# [242]	validation_0-rmse:0.01936	validation_1-rmse:0.02789
# [243]	validation_0-rmse:0.01932	validation_1-rmse:0.02773
# [244]	validation_0-rmse:0.01927	validation_1-rmse:0.02756
# [245]	validation_0-rmse:0.01922	validation_1-rmse:0.02741
# [246]	validation_0-rmse:0.01918	validation_1-rmse:0.02721
# [247]	validation_0-rmse:0.01913	validation_1-rmse:0.02704
# [248]	validation_0-rmse:0.01909	validation_1-rmse:0.02690
# [249]	validation_0-rmse:0.01905	validation_1-rmse:0.02673
# [250]	validation_0-rmse:0.01900	validation_1-rmse:0.02658
# [251]	validation_0-rmse:0.01896	validation_1-rmse:0.02640
# [252]	validation_0-rmse:0.01892	validation_1-rmse:0.02624
# [253]	validation_0-rmse:0.01888	validation_1-rmse:0.02611
# [254]	validation_0-rmse:0.01884	validation_1-rmse:0.02596
# [255]	validation_0-rmse:0.01880	validation_1-rmse:0.02582
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9421561675144147, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.011827896600947194, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=256, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
results = xgb_model.evals_result()

# %%
train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("RMSE Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 2 Days Prediction

# %%
y_pred2 = xgb_model.predict(X_test2)

# %%
rmse = np.sqrt(mean_squared_error(y_test2, y_pred2))
mse = mean_squared_error(y_test2, y_pred2) 
mape = mean_absolute_percentage_error(y_test2, y_pred2)
r2 = r2_score(y_test2, y_pred2)

# %%
print(f" RMSE:{rmse},\n MSE:{mse},\n MAPE:{mape*100}%,\n R-Squared:{r2}")
# Out:
#  RMSE:0.017167016727874292,
#  MSE:0.00029470646333511577,
#  MAPE:1.6967572018059651%,
#  R-Squared:0.7885320344536818

# %%
import matplotlib.pyplot as plt

# Plot Actual vs Predicted Demand
plt.figure(figsize=(12, 6))
plt.plot(y_test2.flatten(), label='Actual Demand', color='blue', alpha=0.7)
plt.plot(y_pred2.flatten(), label='Predicted Demand', color='orange', alpha=0.7)
plt.title('Actual vs Predicted Demand')
plt.xlabel('Time Steps')
plt.ylabel('Demand (MW)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7 days prediction

# %%
y_pred7 = xgb_model.predict(X_test7)

# %%
rmse = np.sqrt(mean_squared_error(y_test7, y_pred7))
mse = mean_squared_error(y_test7, y_pred7) 
mape = mean_absolute_percentage_error(y_test7, y_pred7)
r2 = r2_score(y_test7, y_pred7)

# %%
print(f" RMSE:{rmse},\n MSE:{mse},\n MAPE:{mape*100}%,\n R-Squared:{r2}")
# Out:
#  RMSE:0.02725029115277867,
#  MSE:0.0007425783679112076,
#  MAPE:2.669220731214891%,
#  R-Squared:0.8470511326115662

# %%
import matplotlib.pyplot as plt

# Plot Actual vs Predicted Demand
plt.figure(figsize=(12, 6))
plt.plot(y_test7.flatten(), label='Actual Demand', color='blue', alpha=0.7)
plt.plot(y_pred7.flatten(), label='Predicted Demand', color='orange', alpha=0.7)
plt.title('Actual vs Predicted Demand')
plt.xlabel('Time Steps')
plt.ylabel('Demand (MW)')
plt.legend()
plt.grid(True)
plt.show()
